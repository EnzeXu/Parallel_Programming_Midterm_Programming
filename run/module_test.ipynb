# %% [markdown]
# ## Module Test
#
# Now there are three part that may introduce errors.
#
# 1. Neuro Network may cause inaccurate.
# 2. The scipy.optimize.minimize may fall to local minimal
# 3. The SPL may find wrong equation.

# %%
# Neuro Network Test
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
with open("results/test4/eval_error.npy", "r") as diff_file:
    diff = eval(diff_file.read())
# print(len(diff))
plt.hist(diff, bins=200, range=(-200, 200))
plt.show()
mse = mean_squared_error(np.zeros(len(diff)), diff)
print(mse**0.5, mse)
# Out:
# 52.0007888340592 2704.082039364416
